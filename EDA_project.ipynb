# %%
import pandas as pd 
import seaborn as sns

# %%
df= pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# /var/folders/q0/_kb_t6ps1tnfvhf3429bcqb80000gn/T/ipykernel_11538/784964625.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
# dataset  has been imported

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.tail(10)
# Out:
#          Year of event Event dates                                Event name  \
# 7461185           1995  07.01.1995          Avalon Benefit 50-Mile Run (USA)
# 7461186           1995  00.00.1995           Supermaraton Zagreb-Cazma (CRO)
# 7461187           1995  00.00.1995           Supermaraton Zagreb-Cazma (CRO)
# 7461188           1995  00.00.1995          Les 24 heures de Fleurbaix (FRA)
# 7461189           1995  00.00.1995          Les 24 heures de Fleurbaix (FRA)
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df.shape
# Out:
# (7461195, 13)

# %%
# since it is a bigdata , let us do the clean up

# %%
df.isna()
# Out:
#          Year of event  Event dates  Event name  Event distance/length  \
# 0                False        False       False                  False
# 1                False        False       False                  False
# 2                False        False       False                  False
# 3                False        False       False                  False
# 4                False        False       False                  False
# ...                ...          ...         ...                    ...
# 7461190          False        False       False                  False
# 7461191          False        False       False                  False
# 7461192          False        False       False                  False
# 7461193          False        False       False                  False
# 7461194          False        False       False                  False
#
#          Event number of finishers  Athlete performance  Athlete club  \
# ...

# %%
df.isna().sum()
# Out:
# Year of event                      0
# Event dates                        0
# Event name                         0
# Event distance/length           1053
# Event number of finishers          0
# Athlete performance                2
# Athlete club                 2826524
# Athlete country                    3
# Athlete year of birth         588161
# Athlete gender                     7
# Athlete age category          584938
# Athlete average speed            224
# Athlete ID                         0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#          Year of event Event dates                        Event name  \
# 5                 2018  06.01.2018               Selva Costera (CHI)
# 11                2018  06.01.2018               Selva Costera (CHI)
# 16                2018  06.01.2018               Selva Costera (CHI)
# 19                2018  06.01.2018               Selva Costera (CHI)
# 20                2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461187           1995  00.00.1995   Supermaraton Zagreb-Cazma (CRO)
# 7461188           1995  00.00.1995  Les 24 heures de Fleurbaix (FRA)
# 7461189           1995  00.00.1995  Les 24 heures de Fleurbaix (FRA)
# 7461190           1995  00.00.1995         La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995         La SainteLyon 65 km (FRA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Only want USA Races, 50k or 50Mi, 2020

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
distance=df['Event distance/length'].isin(['50km','50mi'])   #filtering required data using isin() method 
df[distance]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# now lets us filter (USA)

# %%
country=df['Event name'].str.contains('USA', na=False)
df[country]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# let us set the index to year for filtering the data by year and will make it permanent later (inplace= True)

# %%
df.set_index('Year of event')
# Out:
#               Event dates                                Event name  \
# Year of event
# 2018           06.01.2018                       Selva Costera (CHI)
# 2018           06.01.2018                       Selva Costera (CHI)
# 2018           06.01.2018                       Selva Costera (CHI)
# 2018           06.01.2018                       Selva Costera (CHI)
# 2018           06.01.2018                       Selva Costera (CHI)
# ...                   ...                                       ...
# 1995           00.00.1995                 La SainteLyon 65 km (FRA)
# 1995           00.00.1995                 La SainteLyon 65 km (FRA)
# 1995           00.00.1995  Szombathely 24 hours running Race  (HUN)
# 1995           00.00.1995  Szombathely 24 hours running Race  (HUN)
# 1995           00.00.1995  Szombathely 24 hours running Race  (HUN)
#
#               Event distance/length  Event number of finishers  \
# Year of event
# ...

# %%
# combining two filters (country & distance)

# %%
df1=df[(country)&(distance)] 
df1
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df2=df1[df1['Year of event']==2020]
df2
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26524, 13)

# %%
df2.isna().sum()
# Out:
# Year of event                   0
# Event dates                     0
# Event name                      0
# Event distance/length           0
# Event number of finishers       0
# Athlete performance             0
# Athlete club                 3130
# Athlete country                 0
# Athlete year of birth         235
# Athlete gender                  0
# Athlete age category          218
# Athlete average speed           0
# Athlete ID                      0
# dtype: int64

# %%
#remove USA from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26524, dtype: object

# %%
df2['Event name']=df2['Event name'].str.split('(').str.get(0)
# Out:
# /var/folders/q0/_kb_t6ps1tnfvhf3429bcqb80000gn/T/ipykernel_11538/2517910487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name']=df2['Event name'].str.split('(').str.get(0)

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df2['Athlete age category'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 2539945     M23
# 2539946     M35
# 2539947    MU23
# 2539948     M35
# 2539949     M40
#            ...
# 2760957     W60
# 2760958     W40
# 2760959     W55
# 2760960     W35
# 2760961     M35
# Name: Athlete age category, Length: 26524, dtype: object>

# %%
#clean up Athlete age category

# %%
df2['Athlete age category'] = 2024 - df2['Athlete year of birth']
# Out:
# /var/folders/q0/_kb_t6ps1tnfvhf3429bcqb80000gn/T/ipykernel_11538/210571058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete age category'] = 2024 - df2['Athlete year of birth']

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# cleaning up athlete performance

# %%
df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# /var/folders/q0/_kb_t6ps1tnfvhf3429bcqb80000gn/T/ipykernel_11538/2382045920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
 #drop columns: Athlete Club, Athlete Country, Athlete year of birth,

# %%
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth'], axis=1, errors='ignore')

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
df2.isna().sum()  # clean up null values
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete age category         235
# Athlete average speed          0
# Athlete ID                     0
# dtype: int64

# %%
df2.isna().any(axis=1)
# Out:
# 2539945    False
# 2539946    False
# 2539947    False
# 2539948    False
# 2539949    False
#            ...
# 2760957    False
# 2760958    False
# 2760959    False
# 2760960    False
# 2760961    False
# Length: 26524, dtype: bool

# %%
df2[df2.isna().any(axis=1)]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2=df2.dropna()

# %%
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete age category         0
# Athlete average speed        0
# Athlete ID                   0
# dtype: int64

# %%
df2.shape
# Out:
# (26289, 10)

# %%
df2[df2.duplicated() ==True]  #check for duplicates
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
# resetting index

# %%
df2.reset_index(drop=True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 26284           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26285           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26286           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26287           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26288           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2.rename(columns={'Athlete age category':'Athlete age'},inplace=True)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete age                  float64
# Athlete average speed        float64
# Athlete ID                     int64
# dtype: object

# %%
#renaming columns  


#Year of event                  
#Event dates                  
#Event name                   
#Event distance/length       
#Event number of finishers     
#Athlete performance           
#Athlete club                 
#Athlete country          
#Athlete year of birth      
#Athlete gender              
#Athlete age               
#Athlete average speed        
#Athlete ID                    
#Athlete age category

# %%
df2 = df2.rename(columns = {'Year of event': 'year',
                            'Event dates': 'race_day',
                            'Event name': 'race_name',
                            'Event distance/length': 'race_length',
                            'Event number of finishers': 'race_number_of_finishers',
                            'Athlete performance': 'athlete_performance',
                            'Athlete gender': 'athlete_gender',
                            'Athlete age': 'Athelete_age' ,
                            'Athlete average speed': 'athlete_average_speed',
                            'Athlete ID': 'athlete_id'
                            })

# %%
df2.head()
# Out:
#          year    race_day                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_length  race_number_of_finishers athlete_performance  \
# 2539945        50km                        20             3:17:55
# 2539946        50km                        20             4:02:32
# 2539947        50km                        20             4:07:57
# 2539948        50km                        20             4:22:02
# 2539949        50km                        20             4:27:34
#
#         athlete_gender  Athelete_age  athlete_average_speed  athlete_id
# 2539945              M          33.0                 15.158       71287
# ...

# %%
df2['Athelete_age'] = df2['Athelete_age'].astype(int)

# %%
df2.dtypes
# Out:
# year                          int64
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# athlete_performance          object
# athlete_gender               object
# Athelete_age                  int64
# athlete_average_speed       float64
# athlete_id                    int64
# dtype: object

# %%
#reorder columns

# %%
df3=df2[['race_name','race_day', 'race_length' ,'race_number_of_finishers','athlete_id','athlete_gender','Athelete_age','athlete_average_speed','athlete_performance']]

# %%
df3
# Out:
#                                         race_name    race_day race_length  \
# 2539945  West Seattle Beach Run - Winter Edition   02.02.2020        50km
# 2539946  West Seattle Beach Run - Winter Edition   02.02.2020        50km
# 2539947  West Seattle Beach Run - Winter Edition   02.02.2020        50km
# 2539948  West Seattle Beach Run - Winter Edition   02.02.2020        50km
# 2539949  West Seattle Beach Run - Winter Edition   02.02.2020        50km
# ...                                           ...         ...         ...
# 2760957   Yankee Springs Fall Trail Run Festival   03.10.2020        50km
# 2760958   Yankee Springs Fall Trail Run Festival   03.10.2020        50km
# 2760959   Yankee Springs Fall Trail Run Festival   03.10.2020        50km
# 2760960   Yankee Springs Fall Trail Run Festival   03.10.2020        50km
# 2760961   Yankee Springs Fall Trail Run Festival   03.10.2020        50km
#
#          race_number_of_finishers  athlete_id athlete_gender  Athelete_age  \
# ...

# %%
#time to get into data visualization (charts and graphs) using seaborn library

# %%
sns.histplot(data = df3,x='race_length',hue='athlete_gender')
plt.title('Count of male and Female in (50mi and 50Km) categories')
plt.show()

# %%
import matplotlib.pyplot as plt

sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'], bins=20, kde=True,color='red')
plt.title('Distribution of Athlete Average Speed (50mi Race)')
plt.xlabel('Average Speed')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(11, 6))
sns.barplot(
    data=df3,
    x='race_length',
    y='athlete_average_speed',
    hue='athlete_gender',
    palette='pastel',
    
)

plt.title('Average Athlete Speed by Race Length and Gender')
plt.xlabel('Race Length')
plt.ylabel('Average Speed')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
